# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('/content/superstore.csv')

# %%
df.head()
# Out:
#           Category         City        Country Customer.ID     Customer.Name  \
# 0  Office Supplies  Los Angeles  United States   LS-172304  Lycoris Saunders
# 1  Office Supplies  Los Angeles  United States   MV-174854     Mark Van Huff
# 2  Office Supplies  Los Angeles  United States   CS-121304      Chad Sievert
# 3  Office Supplies  Los Angeles  United States   CS-121304      Chad Sievert
# 4  Office Supplies  Los Angeles  United States   AP-109154    Arthur Prichep
#
#    Discount Market  记录数               Order.Date        Order.ID  ... Sales  \
# 0       0.0     US    1  2011-01-07 00:00:00.000  CA-2011-130813  ...    19
# 1       0.0     US    1  2011-01-21 00:00:00.000  CA-2011-148614  ...    19
# 2       0.0     US    1  2011-08-05 00:00:00.000  CA-2011-118962  ...    21
# 3       0.0     US    1  2011-08-05 00:00:00.000  CA-2011-118962  ...   111
# 4       0.0     US    1  2011-09-29 00:00:00.000  CA-2011-146969  ...     6
#
#     Segment                Ship.Date       Ship.Mode  Shipping.Cost  \
# 0  Consumer  2011-01-09 00:00:00.000    Second Class           4.37
# 1  Consumer  2011-01-26 00:00:00.000  Standard Class           0.94
# 2  Consumer  2011-08-09 00:00:00.000  Standard Class           1.81
# 3  Consumer  2011-08-09 00:00:00.000  Standard Class           4.59
# 4  Consumer  2011-10-03 00:00:00.000  Standard Class           1.32
#
#         State  Sub.Category  Year        Market2 weeknum
# 0  California         Paper  2011  North America       2
# 1  California         Paper  2011  North America       4
# 2  California         Paper  2011  North America      32
# 3  California         Paper  2011  North America      32
# 4  California         Paper  2011  North America      40
#
# [5 rows x 27 columns]

# %%
df.shape
# Out:
# (51290, 27)

# %%
df.describe()
# Out:
#            Discount      记录数        Profit      Quantity       Row.ID  \
# count  51290.000000  51290.0  51290.000000  51290.000000  51290.00000
# mean       0.142908      1.0     28.610982      3.476545  25645.50000
# std        0.212280      0.0    174.340972      2.278766  14806.29199
# min        0.000000      1.0  -6599.978000      1.000000      1.00000
# 25%        0.000000      1.0      0.000000      2.000000  12823.25000
# 50%        0.000000      1.0      9.240000      3.000000  25645.50000
# 75%        0.200000      1.0     36.810000      5.000000  38467.75000
# max        0.850000      1.0   8399.976000     14.000000  51290.00000
#
#               Sales  Shipping.Cost          Year       weeknum
# count  51290.000000   51290.000000  51290.000000  51290.000000
# mean     246.498440      26.375818   2012.777208     31.287112
# std      487.567175      57.296810      1.098931     14.429795
# min        0.000000       0.002000   2011.000000      1.000000
# 25%       31.000000       2.610000   2012.000000     20.000000
# 50%       85.000000       7.790000   2013.000000     33.000000
# 75%      251.000000      24.450000   2014.000000     44.000000
# max    22638.000000     933.570000   2014.000000     53.000000

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
# binary cross entropy = -yilog(yi_hat)-(1-yi)log(1-yi_hat), LF=sigmoid, cross_e = (0.2*0.4*0.7*0.8), log(a*b)=loga+logb, log of vals bet. 0 to 1 = neg, -log(a*b)
# ax+by+c=0
# perceptron loss= max(0,-yi.f(xi)), sum(wi.xi)+b, step_func

# softmax_reg = loss = categ cross_entr, sparse_cat_cross_en = -sum: range - j = 1 to k (yilog(yi_hat)), softmax - multiclass_classific.

# %%
df.select_dtypes(include='object')
# Out:
#               Category         City        Country Customer.ID  \
# 0      Office Supplies  Los Angeles  United States   LS-172304
# 1      Office Supplies  Los Angeles  United States   MV-174854
# 2      Office Supplies  Los Angeles  United States   CS-121304
# 3      Office Supplies  Los Angeles  United States   CS-121304
# 4      Office Supplies  Los Angeles  United States   AP-109154
# ...                ...          ...            ...         ...
# 51285  Office Supplies  Los Angeles  United States   AM-103604
# 51286  Office Supplies  Los Angeles  United States   AM-103604
# 51287  Office Supplies  Los Angeles  United States   HR-147704
# 51288  Office Supplies  Los Angeles  United States   RM-196754
# 51289  Office Supplies  Los Angeles  United States   FH-143654
#
#           Customer.Name Market               Order.Date        Order.ID  \
# 0      Lycoris Saunders     US  2011-01-07 00:00:00.000  CA-2011-130813
# 1         Mark Van Huff     US  2011-01-21 00:00:00.000  CA-2011-148614
# 2          Chad Sievert     US  2011-08-05 00:00:00.000  CA-2011-118962
# 3          Chad Sievert     US  2011-08-05 00:00:00.000  CA-2011-118962
# 4        Arthur Prichep     US  2011-09-29 00:00:00.000  CA-2011-146969
# ...                 ...    ...                      ...             ...
# 51285    Alice McCarthy     US  2014-12-03 00:00:00.000  CA-2014-109701
# 51286    Alice McCarthy     US  2014-12-03 00:00:00.000  CA-2014-109701
# 51287    Hallie Redmond     US  2014-12-18 00:00:00.000  CA-2014-106964
# 51288     Robert Marley     US  2014-12-25 00:00:00.000  CA-2014-145219
# 51289      Fred Hopkins     US  2014-12-26 00:00:00.000  CA-2014-121398
#
#       Order.Priority       Product.ID  \
# 0               High  OFF-PA-10002005
# 1             Medium  OFF-PA-10002893
# 2             Medium  OFF-PA-10000659
# 3             Medium  OFF-PA-10001144
# 4               High  OFF-PA-10002105
# ...              ...              ...
# 51285           High  OFF-BI-10000632
# 51286           High  OFF-BI-10004187
# 51287         Medium  OFF-BI-10000320
# 51288       Critical  OFF-BI-10001670
# 51289         Medium  OFF-BI-10001718
#
#                                             Product.Name Region      Segment  \
# 0                                              Xerox 225   West     Consumer
# 1              Wirebound Service Call Books, 5 1/2" x 4"   West     Consumer
# 2      Adams Phone Message Book, Professional, 400 Me...   West     Consumer
# 3                                             Xerox 1913   West     Consumer
# 4                                              Xerox 223   West     Consumer
# ...                                                  ...    ...          ...
# 51285                   Satellite Sectional Post Binders   West    Corporate
# 51286                                            Staples   West    Corporate
# 51287                          GBC Plastic Binding Combs   West  Home Office
# 51288                       Vinyl Sectional Post Binders   West  Home Office
# 51289          GBC DocuBind P50 Personal Binding Machine   West    Corporate
#
#                      Ship.Date       Ship.Mode       State Sub.Category  \
# 0      2011-01-09 00:00:00.000    Second Class  California        Paper
# 1      2011-01-26 00:00:00.000  Standard Class  California        Paper
# 2      2011-08-09 00:00:00.000  Standard Class  California        Paper
# 3      2011-08-09 00:00:00.000  Standard Class  California        Paper
# 4      2011-10-03 00:00:00.000  Standard Class  California        Paper
# ...                        ...             ...         ...          ...
# 51285  2014-12-04 00:00:00.000        Same Day  California      Binders
# 51286  2014-12-04 00:00:00.000        Same Day  California      Binders
# 51287  2014-12-21 00:00:00.000     First Class  California      Binders
# 51288  2014-12-26 00:00:00.000     First Class  California      Binders
# 51289  2014-12-30 00:00:00.000  Standard Class  California      Binders
#
#              Market2
# 0      North America
# 1      North America
# 2      North America
# 3      North America
# 4      North America
# ...              ...
# 51285  North America
# 51286  North America
# 51287  North America
# 51288  North America
# 51289  North America
#
# [51290 rows x 18 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 27 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Category        51290 non-null  object
#  1   City            51290 non-null  object
#  2   Country         51290 non-null  object
#  3   Customer.ID     51290 non-null  object
#  4   Customer.Name   51290 non-null  object
#  5   Discount        51290 non-null  float64
#  6   Market          51290 non-null  object
#  7   记录数             51290 non-null  int64
#  8   Order.Date      51290 non-null  object
#  9   Order.ID        51290 non-null  object
#  10  Order.Priority  51290 non-null  object
#  11  Product.ID      51290 non-null  object
#  12  Product.Name    51290 non-null  object
#  13  Profit          51290 non-null  float64
#  14  Quantity        51290 non-null  int64
#  15  Region          51290 non-null  object
#  16  Row.ID          51290 non-null  int64
#  17  Sales           51290 non-null  int64
#  18  Segment         51290 non-null  object
#  19  Ship.Date       51290 non-null  object
#  20  Ship.Mode       51290 non-null  object
#  21  Shipping.Cost   51290 non-null  float64
#  22  State           51290 non-null  object
#  23  Sub.Category    51290 non-null  object
#  24  Year            51290 non-null  int64
#  25  Market2         51290 non-null  object
#  26  weeknum         51290 non-null  int64
# dtypes: float64(3), int64(6), object(18)
# memory usage: 10.6+ MB

# %%
df.isnull().sum()
# Out:
# Category          0
# City              0
# Country           0
# Customer.ID       0
# Customer.Name     0
# Discount          0
# Market            0
# 记录数               0
# Order.Date        0
# Order.ID          0
# Order.Priority    0
# Product.ID        0
# Product.Name      0
# Profit            0
# Quantity          0
# Region            0
# Row.ID            0
# Sales             0
# Segment           0
# Ship.Date         0
# Ship.Mode         0
# Shipping.Cost     0
# State             0
# Sub.Category      0
# Year              0
# Market2           0
# weeknum           0
# dtype: int64

# %%
df.drop(columns=['记录数'],inplace=True)

# %%
sns.boxplot(df['Year'])
# Out:
# <Axes: ylabel='Year'>

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %%
for i in df.select_dtypes(exclude='object').columns:
  plt.figure(figsize=(6,6))
  sns.boxplot(x=df[i])
  plt.title(f'boxplot of {i}')
  plt.plot()

# %%
for i in df.select_dtypes(include='object'):
  x=df[i].unique()
  print(f'{i}:{x}')
# Out:
# Category:['Office Supplies' 'Technology' 'Furniture']
# City:['Los Angeles' 'San Francisco' 'San Diego' ... 'Ontario' 'Whittier'
#  'Redwood City']
# Country:['United States' 'France' 'Germany' 'El Salvador' 'Guatemala' 'Austria'
#  'Nicaragua' 'Belgium' 'Switzerland' 'Italy' 'South Africa' 'India'
#  'Hong Kong' 'Democratic Republic of the Congo' 'Cuba' 'United Kingdom'
#  'Spain' 'Russia' 'China' 'Niger' 'Qatar' 'New Zealand' 'Mexico'
#  'Malaysia' 'Poland' 'Madagascar' 'Iraq' 'Brazil' 'Colombia'
#  'Saudi Arabia' 'Egypt' 'Iran' 'Ukraine' 'Japan' 'Morocco' 'Cameroon'
#  'Chile' 'Ghana' 'Trinidad and Tobago' 'Canada' 'Chad' 'Kenya'
#  'Bangladesh' 'Bulgaria' 'Djibouti' 'Uruguay' 'Singapore' 'Czech Republic'
#  'Zambia' 'Bolivia' 'Angola' 'Australia' 'Tanzania' 'Norway'
#  'Sierra Leone' 'Hungary' 'Ecuador' 'Finland' 'Afghanistan' 'Uzbekistan'
#  'Romania' 'Kyrgyzstan' 'Belarus' 'Mongolia' 'Georgia' 'Syria' 'Croatia'
#  'Israel' 'Liberia' 'Guinea-Bissau' 'Somalia' 'Senegal' 'Tunisia' 'Mali'
#  'Algeria' 'Benin' 'Ethiopia' 'Libya' 'Mozambique' 'Guadeloupe' 'Jordan'
#  'Togo' "Cote d'Ivoire" 'Taiwan' 'Jamaica' 'Cambodia' 'Azerbaijan'
#  'Lesotho' 'Bahrain' 'Montenegro' 'Moldova' 'Rwanda' 'Nepal' 'Martinique'
#  'Estonia' 'Albania' 'Slovakia' 'Sudan' 'Guinea' 'Republic of the Congo'
#  'Namibia' 'Sri Lanka' 'Central African Republic' 'Eritrea' 'Lebanon'
#  'Bosnia and Herzegovina' 'Barbados' 'Paraguay' 'Mauritania' 'Swaziland'
#  'Gabon' 'Armenia' 'Slovenia' 'Macedonia' 'Equatorial Guinea'
#  'South Sudan' 'Burundi' 'Turkey' 'Nigeria' 'Turkmenistan' 'Kazakhstan'
#  'Lithuania' 'Yemen' 'Uganda' 'Zimbabwe' 'United Arab Emirates' 'Sweden'
#  'Denmark' 'Ireland' 'Portugal' 'Netherlands' 'South Korea' 'Pakistan'
#  'Papua New Guinea' 'Thailand' 'Myanmar (Burma)' 'Vietnam' 'Philippines'
#  'Indonesia' 'Dominican Republic' 'Haiti' 'Panama' 'Honduras' 'Argentina'
#  'Peru' 'Venezuela' 'Tajikistan']
# Customer.ID:['LS-172304' 'MV-174854' 'CS-121304' ... 'JR-157004' 'CJ-118754'
#  'AO-108104']
# Customer.Name:['Lycoris Saunders' 'Mark Van Huff' 'Chad Sievert' 'Arthur Prichep'
#  'Jeremy Farry' 'William Brown' 'Joseph Airdo' 'Susan Pistek' 'Rob Lucas'
#  'Katherine Ducich' 'Justin MacKendrick' 'Rob Dowd' 'Alan Barnes'
#  'Andy Reiter' 'Logan Haushalter' 'Andrew Roberts' 'Nathan Gelder'
#  'Darren Powers' 'Toby Swindell' 'Kunst Miller' 'Arianne Irving'
#  'Clay Ludtke' 'Scot Wooten' 'Chris Cortes' 'Logan Currie'
#  'Jason Fortune-' "Jas O'Carroll" 'Trudy Brown' 'Ted Trevino'
#  'Denny Ordway' 'Lynn Smith' 'Olvera Toch' 'Bill Donatelli'
#  'Mike Vittorini' 'Guy Thornton' 'Christopher Conant' 'Jill Matthias'
#  'Pamela Stobb' 'Cindy Chapman' 'Joel Eaton' 'Xylona Preis'
#  "Sean O'Donnell" 'Clytie Kelty' 'Lauren Leatherbury' 'Dorothy Dickinson'
#  'Dianna Vittorini' 'Craig Carreira' 'Thomas Thornton' 'Tracy Blumstein'
#  'Kean Thornton' 'Liz Carlisle' 'John Murray' 'Duane Benoit'
#  'Guy Armstrong' 'Emily Phan' 'Clay Cheatham' 'Steven Roelle' 'Andy Yotov'
#  'Aaron Hawkins' 'Vicky Freymann' 'Janet Molinari' 'Greg Guthrie'
#  'Paul Lucas' 'Matt Abelman' 'Mike Caudle' 'Alice McCarthy' 'Bart Pistole'
#  'Deanra Eno' 'Anthony Jacobs' 'Catherine Glotzbach' "Meg O'Connel"
#  'Rick Wilson' 'Yoseph Carroll' 'Steve Nguyen' 'Darren Budd' 'Sean Miller'
#  'Sample Company A' 'Suzanne McNair' 'Ross DeVincentis' 'Karen Ferguson'
#  'Ricardo Sperren' 'Nancy Lomonaco' 'Ross Baird' 'Adam Hart' 'Scot Coram'
#  'Jim Sink' 'Laura Armstrong' 'Carl Weiss' 'Tiffany House' 'Anne Pryor'
#  'Henry Goldwyn' 'Grace Kelly' 'Bradley Talbott' 'Noel Staavos'
#  'Saphhira Shifley' 'Roland Schwarz' 'Chris Selesnick' 'Rick Bensley'
#  'Frank Hawley' 'John Lee' 'Marc Harrigan' 'Brosina Hoffman'
#  'Filia McAdams' 'Anthony Rawles' 'Alejandro Ballentine' 'Tracy Collins'
#  'Richard Bierner' 'Frank Preis' 'Michael Chen' 'Annie Zypern'
#  'Pauline Chand' 'George Bell' 'Skye Norling' 'Frank Carlisle'
#  'Paul Gonzalez' 'Pauline Webber' 'Tom Stivers' 'Lena Radford'
#  'Carlos Soltero' 'Tim Brockman' 'Maribeth Schnelling' 'Fred Hopkins'
#  'Tonja Turnell' 'Emily Ducich' 'Sung Pak' 'Barry Pond' 'Tom Boeckenhauer'
#  'Erin Ashbrook' 'Ben Wallace' 'Stuart Calhoun' 'Dave Poirier'
#  'Sonia Cooley' 'Robert Waldorf' 'Zuschuss Carroll' 'Joe Elijah'
#  'Alyssa Tate' 'Bradley Nguyen' "Patrick O'Donnell" 'Paul Stevenson'
#  'Barry Blumstein' 'Todd Sumrall' 'Shahid Shariari' 'Justin Deggeller'
#  'Sanjit Chand' 'Joni Blumstein' 'Cynthia Delaney' 'Muhammed MacIntyre'
#  'Christopher Schild' 'Charlotte Melton' 'Harry Marie' 'Karen Daniels'
#  'Matt Collins' 'Matthew Clasen' 'Darrin Van Huff' 'Larry Blacks'
#  'Phillip Flathmann' 'Eudokia Martin' 'Julie Prescott' 'Cynthia Voltz'
#  'Jason Klamczynski' 'Steven Cartwright' 'Michelle Tran'
#  'Zuschuss Donatelli' 'George Ashbrook' 'Joy Bell-' 'Brendan Murry'
#  'Gary Hansen' 'Ben Ferrer' 'Bill Tyler' 'Linda Southworth'
#  'Hunter Glantz' 'Sarah Brown' 'Charles Crestani' 'Anne McFarland'
#  'Yana Sorensen' 'Arthur Gainer' 'Anna Häberlin' 'Jonathan Howell'
#  'Sarah Bern' 'Ken Dana' 'Katherine Nockton' 'Ralph Arnett'
#  'Keith Dawkins' 'Paul Van Hugh' 'Katrina Edelman' 'Michelle Arnett'
#  'Julie Creighton' 'Ann Blume' 'Tim Taslimi' 'Cassandra Brandow'
#  'Shaun Chance' 'Roy Phan' 'Robert Marley' 'Kean Takahito'
#  'Jennifer Braxton' 'Tracy Zic' 'Barry Franz' 'Alan Shonely'
#  'Ruben Ausman' 'Khloe Miller' 'Cathy Armstrong' 'Edward Hooks'
#  'Jonathan Doherty' 'Matt Connell' 'Gary McGarr' 'George Zrebassa'
#  'Annie Thurman' 'Karen Bern' 'Cindy Stewart' 'Mick Crebagga'
#  'Brian Dahlen' 'Christina Anderson' 'Damala Kotsonis' 'Alex Avila'
#  'Paul Knutson' 'Chuck Magee' 'Darrin Sayre' 'Michelle Ellison'
#  'Naresj Patel' 'Nick Crebassa' 'Ken Lonsdale' 'Sonia Sunley'
#  'Victoria Pisteka' 'Dennis Pardue' 'Jim Kriz' 'Erica Smith'
#  'Herbert Flentye' 'Julia Dunbar' 'Shirley Jackson' 'Duane Noonan'
#  'Rachel Payne' 'Shahid Hopkins' 'Jeremy Pistek' 'Scott Cohen'
#  'Thomas Seio' 'Duane Huffman' 'Sheri Gordon' 'Alan Hwang'
#  'Anthony Johnson' 'James Lanier' 'Ken Black' "Patrick O'Brill"
#  'Lena Cacioppo' 'Helen Andreada' 'David Smith' 'David Bremer'
#  'Rick Huthwaite' 'Nona Balk' 'Ashley Jarboe' 'Art Ferguson' 'Meg Tillman'
#  'Theresa Swint' 'Dean Katz' 'Brian Thompson' 'Eric Barreto' 'Ruben Dartt'
#  'Anna Andreadi' 'Raymond Buch' 'Dionis Lloyd' 'Becky Castell'
#  'Rob Williams' 'Pete Kriz' 'Sam Zeldin' 'Chuck Clark' 'Greg Maxwell'
#  'Julia West' 'Pamela Coakley' "Rose O'Brian" 'Ralph Ritter' 'Heather Jas'
#  'Mike Kennedy' 'Doug Bickford' 'Stefania Perrino' 'Christopher Martinez'
#  'Tamara Manning' 'Caroline Jumper' 'Vivek Gonzalez' 'Michael Moore'
#  'Eugene Hildebrand' 'Sally Hughsby' 'Bill Stewart' 'Jesus Ocampo'
#  'Don Jones' 'Darren Koutras' 'Michelle Moray' 'Charles Sheldon'
#  'Matt Hagelstein' 'Erin Creighton' 'Eric Murdock' 'Bruce Degenhardt'
#  'Jay Kimmel' 'Nora Preis' 'Lisa Ryan' 'Maxwell Schwartz'
#  'Aleksandra Gannaway' 'Rick Duston' 'Craig Yedwab' 'Bruce Stewart'
#  'Neil Knudson' 'Frank Gastineau' 'Hilary Holden' 'Jamie Kunitz'
#  'Frank Merwin' 'Patrick Jones' 'Patrick Gardner' 'Bradley Drucker'
#  'Victoria Wilson' 'Keith Herrera' 'Alan Schoenberger' 'Denise Monton'
#  'Gary Zandusky' 'Kristen Hastings' 'Nathan Mautz' 'Roger Demir'
#  'Georgia Rosenberg' 'Steve Carroll' 'Lindsay Shagiari' 'Erica Hernandez'
#  'Cyma Kinney' 'Nick Zandusky' 'Denny Joy' 'Greg Tran' 'Karen Carlisle'
#  'Dorothy Wardle' 'Alejandro Savely' 'Adrian Hane' 'Alan Dominguez'
#  'Lindsay Williams' 'Troy Staebel' 'Mike Pelletier' 'Patrick Ryan'
#  'Ed Jacobs' 'Deborah Brumfield' 'Maya Herman' 'Thea Hendricks'
#  'Adam Shillingsburg' 'Bart Watters' 'Bruce Geld' 'Philip Fox'
#  'Sean Braxton' 'Bryan Spruell' 'Jay Fein' 'Maria Zettner' 'John Grady'
#  'Brian Stugart' 'Dennis Kane' 'Michael Granlund' 'Julie Kriz'
#  'Ivan Gibson' 'Max Jones' 'Kelly Collister' 'Jane Waco' 'Irene Maddox'
#  'Kelly Andreada' 'Shaun Weien' 'Astrea Jones' 'Scott Williamson'
#  'Toby Carlisle' 'Beth Thompson' 'Greg Matthias' 'Larry Tron'
#  'Nick Radford' 'Frank Atkinson' 'Sanjit Engle' 'David Flashing'
#  'Tanja Norvell' 'Laurel Workman' 'Luke Schmidt' 'Maribeth Dona'
#  'Berenike Kampe' 'Nathan Cano' 'Stephanie Phelps' 'Christine Sundaresam'
#  'Odella Nelson' 'Richard Eichhorn' 'Ryan Akin' 'Neoma Murray'
#  'Trudy Glocke' 'Maribeth Yedwab' 'Sandra Glassco' 'Mary Zewe'
#  'Eileen Kiefer' 'Helen Abelman' 'Dianna Wilson' 'Vivian Mathis'
#  'Stewart Visinsky' 'Chloris Kastensmidt' 'Roy Collins' 'Roland Fjeld'
#  'Laurel Beltran' 'Joseph Holt' 'Liz Preis' 'Eugene Barchas' 'Dan Lawera'
#  'Daniel Byrd' 'Lena Creighton' 'Roy Französisch' 'Jasper Cacioppo'
#  'Sean Christensen' 'Eugene Moren' 'Frank Olsen' 'Jamie Frazer'
#  'Fred Chung' 'Becky Martin' 'Christina VanderZanden' 'Dave Hallsten'
#  'Luke Weiss' 'Trudy Schmidt' 'Nicole Hansen' 'Jeremy Lonsdale'
#  'Dan Reichenbach' 'Anthony Witt' 'Eva Jacobs' 'Joe Kamberova'
#  'Neola Schneider' 'Marc Crier' 'Justin Ellison' 'Matt Collister'
#  'Thomas Brumley' 'Brenda Bowman' 'Brad Norvell' 'Luke Foster'
#  'Kalyca Meade' 'Christine Abelman' 'Sue Ann Reed' 'Gene McClure'
#  'Elizabeth Moffitt' 'Katherine Murray' 'Penelope Sewall' 'Sanjit Jacobs'
#  'Delfina Latchford' 'Dave Brooks' 'Brendan Dodson' 'Carlos Daly'
#  'Katrina Bavinger' 'Ken Heidel' 'Edward Becker' 'Alex Grayson'
#  'Brooke Gillingham' 'Grant Thornton' 'Kristina Nunn' 'Tamara Chand'
#  'Benjamin Venier' 'Nora Pelletier' 'Neil Ducich' 'Bill Eplett'
#  'Aimee Bixby' 'Bryan Mills' 'Daniel Lacy' 'Karl Braun' 'Christy Brittain'
#  'Ted Butterfield' 'Maureen Gnade' 'Natalie DeCherney' 'Emily Grady'
#  'Chris McAfee' 'Joni Wasserman' 'Hunter Lopez' 'Bobby Trafton'
#  'Toby Braunhardt' 'Allen Goldenen' 'Darrin Martin' 'Mitch Webber'
#  'Lisa DeCherney' 'Katharine Harms' 'Philip Brown' 'Lindsay Castell'
#  'John Huston' 'John Lucas' 'Natalie Webber' 'Edward Nazzal'
#  'Tracy Hopkins' 'Brendan Sweed' 'Andy Gerbode' 'Peter Fuller'
#  'Jennifer Jackson' 'Philisse Overcash' 'Mark Cousins' 'Rick Reed'
#  'Thomas Boland' 'Cindy Schnelling' 'Sally Matthias' 'Stephanie Ulpright'
#  'Steven Ward' 'Helen Wasserman' 'Jennifer Patt' 'Michael Grace'
#  'Corinna Mitchell' 'Denny Blanton' 'Harold Ryan' 'Tamara Dahlen'
#  'Sally Knutson' 'Cari Schnelling' 'Ann Chong' 'Seth Vernon'
#  'Katrina Willman' 'Craig Reiter' 'Tom Ashbrook' 'Lori Olson'
#  'Deirdre Greer' 'Chuck Sachs' 'Bart Folk' 'Doug Jacobs'
#  'Jennifer Ferguson' 'Susan Gilcrest' 'Barbara Fisher' 'Erin Mull'
#  'Paul Prost' 'Dan Campbell' 'Sara Luxemburg' 'Nicole Fjeld'
#  'Jessica Myrick' 'Roger Barcio' 'Bobby Odegard' 'Mark Packer'
#  'Brian Moss' 'Jeremy Ellison' 'Don Weiss' 'Sarah Foster'
#  'Liz MacKendrick' 'Denise Leinenbach' 'Todd Boyes' 'Mark Haberlin'
#  'Linda Cazamias' 'Sharelle Roach' 'Resi Pölking' 'Don Miller'
#  'Craig Carroll' 'Dean percer' 'Adrian Barton' 'Sibella Parks'
#  'Fred McMath' 'Parhena Norris' 'Bryan Davis' 'Maria Bertelson'
#  'Ellis Ballard' 'James Galang' 'Amy Hunt' 'Mathew Reese' 'Cyra Reiten'
#  'Victor Preis' 'Christine Phan' 'Barry Weirich' 'Mark Hamilton'
#  'Aaron Smayling' 'Rick Hansen' 'Russell Applegate' 'Chad McGuire'
#  'Monica Federle' 'Valerie Dominguez' 'Amy Cox' 'Janet Lee' 'Brian Derr'
#  'Speros Goranitis' 'Giulietta Baptist' 'Janet Martin' 'Adam Bellavance'
#  'Nat Carroll' 'Roland Murray' 'John Castell' 'Allen Rosenblatt'
#  'Henia Zydlo' 'Becky Pak' 'Harry Greene' 'Christina DeMoss'
#  'Carol Darley' 'Adrian Shami' 'Allen Armold' 'David Kendrick'
#  'Aaron Bergman' 'Bill Shonely' 'Robert Dilbeck' 'Shahid Collister'
#  'Michelle Huthwaite' 'Max Engle' 'Tamara Willingham' 'Candace McMahon'
#  'MaryBeth Skach' 'Valerie Mitchum' 'Liz Pelletier' 'Tom Prescott'
#  'Cari Sayre' 'Ben Peterman' 'Ken Brennan' 'Marina Lichtenstein'
#  'Craig Molinari' 'Dorris liebe' 'Gary Hwang' 'Evan Bailliet'
#  'Joy Daniels' 'Ann Steele' 'Toby Ritter' 'Angele Hood' 'Rob Beeghly'
#  'Fred Harton' 'Dana Kaydos' 'Christine Kargatis' 'Kimberly Carter'
#  'Erica Hackney' 'Jim Karlsson' 'Clay Rozendal' 'Jenna Caffey'
#  'Ionia McGrath' 'Alejandro Grove' 'Neil Französisch' 'Dennis Bolton'
#  'Shui Tom' 'Ivan Liston' 'Patrick Bzostek' 'Kelly Lampkin'
#  'Benjamin Farhat' 'David Wiener' 'Stuart Van' 'Jim Mitchum'
#  'Susan Vittorini' 'Muhammed Yedwab' 'Randy Ferguson' 'Raymond Messe'
#  'Shirley Schmidt' 'Thea Hudgings' 'Jim Epp' 'Maris LaWare'
#  'Claudia Bergmann' 'Pierre Wener' 'Laurel Elliston' 'Brad Eason'
#  'Michael Paige' 'Sylvia Foulston' 'Harold Pawlan' 'Peter McVee'
#  'Brad Thomas' 'Dave Kipp' 'Cathy Prescott' 'Jim Radford'
#  'Maureen Fritzler' 'Daniel Raglin' 'Michael Kennedy' 'Harold Engle'
#  'Tony Chapman' 'Dianna Arnett' 'Michael Nguyen' 'Nat Gilpin'
#  'Dorothy Badders' 'Michael Dominguez' 'Liz Willingham' 'Magdelene Morse'
#  'Gary Mitchum' 'Ed Ludwig' 'Jason Gross' 'Carol Triggs' 'Sung Shariari'
#  'Harold Dahlen' 'Guy Phonely' "Doug O'Connell" 'Eleni McCrary'
#  'Alex Russell' 'Carl Ludwig' 'Sandra Flanagan' 'Corey Roper'
#  'Eric Hoffmann' 'Phillina Ober' 'Erin Smith' 'Shirley Daniels'
#  'Vivek Grady' 'Cynthia Arntzen' 'Liz Thompson' 'Theresa Coyne'
#  'Nora Paige' 'Dean Braden' "Jack O'Briant" 'Robert Barroso' 'Karen Seio'
#  'Lena Hernandez' 'John Stevenson' 'Julia Barnett' 'Anemone Ratner'
#  'Theone Pippenger' 'Debra Catini' 'Victoria Brennan' 'Maria Etezadi'
#  'Mick Hernandez' 'Beth Fritzler' 'Peter Bühler' 'Anna Gayman'
#  'Juliana Krohn' 'Giulietta Weimer' 'Katherine Hughes' 'Maurice Satty'
#  'Fred Wasserman' 'Stewart Carmichael' 'Corey-Lock' 'Joy Smith'
#  'Carol Adams' 'Natalie Fritzler' 'Giulietta Dortch' 'Mitch Willingham'
#  'Anthony Garverick' 'Joel Jenkins' 'Rob Haberlin' 'Max Ludwig'
#  'Jill Fjeld' 'Quincy Jones' 'Evan Minnotte' 'Barry Gonzalez'
#  'Noah Childs' 'Pete Armstrong' 'Ralph Kennedy' 'Steve Chapman'
#  'Anna Chung' 'Chad Cunningham' 'Hallie Redmond' 'Justin Ritter'
#  'Elpida Rittenbach' 'Bill Overfelt' 'Arthur Wiediger' 'Joni Sundaresam'
#  'Kelly Williams' 'Michael Stewart' 'Sean Wendt' 'Andrew Allen'
#  'Mick Brown' 'Benjamin Patterson' 'Tony Molinari' 'Craig Leslie'
#  'Matthew Grinstein' 'Barry Französisch' 'Brian DeCherney' 'Roy Skaria'
#  'Paul MacIntyre' 'Heather Kirkland' 'Sam Craven' 'Dario Medina'
#  'Andrew Gjertsen' 'Ryan Crowe' 'Cathy Hwang' 'Patricia Hirasaki'
#  'Valerie Takahito' 'Maureen Gastineau' 'Carl Jackson' 'Phillip Breyer'
#  'Lela Donovan' 'Tracy Poddar' 'Stefanie Holloman' 'Michelle Lonsdale'
#  'Alan Haines' 'Mitch Gastineau' 'Erica Bern' 'Corey Catlett'
#  'Cari MacIntyre' 'Gene Hale' 'Jill Stevenson' 'Tom Zandusky' 'Ed Braxton'
#  'Kean Nguyen' 'Nicole Brennan' 'Alyssa Crouse' "Anthony O'Donnell"
#  'Lisa Hazard' 'Bobby Elias' "Mary O'Rourke" 'Justin Hirsh'
#  'Melanie Seite' 'Sarah Jordon' 'Jocasta Rupert' 'Muhammed Lee'
#  'Jennifer Halladay' 'Pauline Johnson' "Russell D'Ascenzo" 'Carlos Meador'
#  'Greg Hansen' 'John Dryer' 'Vivek Sundaresam' 'Randy Bradley'
#  'Art Foster' 'Ricardo Emerson' 'Henry MacAllister' 'Jack Lebron'
#  'David Philippe' 'Pete Takahito' 'Larry Hughes' 'Claire Gute'
#  'Charles McCrossin' 'Thais Sissman' 'Mike Gockenbach' 'Susan MacKendrick'
#  'Sung Chung' 'Beth Paige' 'Jack Garza' 'Michael Oakman' 'Ritsa Hightower'
#  'Toby Gnade' 'Emily Burns' 'Troy Blackwell' 'Evan Henry' 'Tony Sayre']
# Market:['US' 'EU' 'LATAM' 'Africa' 'APAC' 'EMEA' 'Canada']
# Order.Date:['2011-01-07 00:00:00.000' '2011-01-21 00:00:00.000'
#  '2011-08-05 00:00:00.000' ... '2012-05-20 00:00:00.000'
#  '2011-10-02 00:00:00.000' '2011-02-13 00:00:00.000']
# Order.ID:['CA-2011-130813' 'CA-2011-148614' 'CA-2011-118962' ... 'CA-2014-137085'
#  'US-2014-136707' 'CA-2014-106964']
# Order.Priority:['High' 'Medium' 'Critical' 'Low']
# Product.ID:['OFF-PA-10002005' 'OFF-PA-10002893' 'OFF-PA-10000659' ...
#  'TEC-MA-10003329' 'FUR-TA-10001691' 'TEC-MA-10001031']
# Product.Name:['Xerox 225' 'Wirebound Service Call Books, 5 1/2" x 4"'
#  'Adams Phone Message Book, Professional, 400 Message Capacity, 5 3/6” x 11”'
#  ... 'Vtech AT&T CL2940 Corded Speakerphone, Black'
#  'Barricks Non-Folding Utility Table with Steel Legs, Laminate Tops'
#  'Socket Bluetooth Cordless Hand Scanner (CHS)']
# Region:['West' 'East' 'South' 'Central' 'Africa' 'Central Asia' 'North Asia'
#  'Caribbean' 'North' 'EMEA' 'Oceania' 'Southeast Asia' 'Canada']
# Segment:['Consumer' 'Home Office' 'Corporate']
# Ship.Date:['2011-01-09 00:00:00.000' '2011-01-26 00:00:00.000'
#  '2011-08-09 00:00:00.000' ... '2011-05-16 00:00:00.000'
#  '2012-07-23 00:00:00.000' '2011-01-03 00:00:00.000']
# Ship.Mode:['Second Class' 'Standard Class' 'Same Day' 'First Class']
# State:['California' 'New York' 'Washington' ... 'Tennessee' 'Oregon' 'Wyoming']
# Sub.Category:['Paper' 'Art' 'Storage' 'Appliances' 'Supplies' 'Envelopes' 'Fasteners'
#  'Labels' 'Binders' 'Accessories' 'Phones' 'Copiers' 'Machines' 'Tables'
#  'Bookcases' 'Chairs' 'Furnishings']
# Market2:['North America' 'EU' 'LATAM' 'Africa' 'APAC' 'EMEA']

# %%
df['Product.ID'].nunique()
# Out:
# 10292

# %%
for i in df.select_dtypes(include='object'):
  x=df[i].nunique()
  if x < 100:
   print(f'{i}:{x}')
# Out:
# Category:3
# Market:7
# Order.Priority:4
# Region:13
# Segment:3
# Ship.Mode:4
# Sub.Category:17
# Market2:6

# %%
sns.distplot(df['Discount'])
# Out:
# <ipython-input-226-88953e8c0432>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Discount'])
# <Axes: xlabel='Discount', ylabel='Density'>

# %%
sns.distplot(df['Quantity'])
# Out:
# <ipython-input-227-f3bec4447d1e>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Quantity'])
# <Axes: xlabel='Quantity', ylabel='Density'>

# %%
df['Quantity'].skew(),df['Discount'].skew()
# Out:
# (1.3603677307024198, 1.387774552133838)

# %%
df[['Discount','Quantity']].describe()
# Out:
#            Discount      Quantity
# count  51290.000000  51290.000000
# mean       0.142908      3.476545
# std        0.212280      2.278766
# min        0.000000      1.000000
# 25%        0.000000      2.000000
# 50%        0.000000      3.000000
# 75%        0.200000      5.000000
# max        0.850000     14.000000

# %% [markdown]
# # **Outlier_Detection and removal using IQR**

# %%
# Discount :

# %%
perc75=df['Discount'].quantile(0.75)
perc25=df['Discount'].quantile(0.25)
perc75,perc25
# Out:
# (0.2, 0.0)

# %%
iqr=perc75-perc25
iqr
# Out:
# 0.2

# %%
upper_limit=perc75+1.5*iqr
lower_limit=perc25-1.5*iqr
upper_limit,lower_limit
# Out:
# (0.5, -0.30000000000000004)

# %%
df[df['Discount']>upper_limit]
# Out:
#               Category          City        Country Customer.ID  \
# 29117        Furniture         Reims         France   HG-150252
# 29120        Furniture      Toulouse         France   RH-194952
# 29122        Furniture      Toulouse         France   NS-186402
# 29125       Technology       Le Mans         France   MG-176802
# 29127       Technology      Toulouse         France   JG-158052
# ...                ...           ...            ...         ...
# 47628  Office Supplies       Orlando  United States   DK-130904
# 47629  Office Supplies   Chattanooga  United States   CA-122654
# 47630  Office Supplies       Memphis  United States   MY-173804
# 47631  Office Supplies         Tampa  United States   DB-129104
# 47632  Office Supplies  Fayetteville  United States   MC-175754
#
#             Customer.Name  Discount Market               Order.Date  \
# 29117       Hunter Glantz      0.60     EU  2011-01-26 00:00:00.000
# 29120         Rick Hansen      0.60     EU  2012-03-29 00:00:00.000
# 29122        Noel Staavos      0.60     EU  2012-08-23 00:00:00.000
# 29125   Maureen Gastineau      0.65     EU  2012-12-22 00:00:00.000
# 29127          John Grady      0.65     EU  2013-06-19 00:00:00.000
# ...                   ...       ...    ...                      ...
# 47628           Dave Kipp      0.70     US  2014-11-04 00:00:00.000
# 47629  Christina Anderson      0.70     US  2014-11-05 00:00:00.000
# 47630     Maribeth Yedwab      0.70     US  2014-11-25 00:00:00.000
# 47631         Daniel Byrd      0.70     US  2014-12-03 00:00:00.000
# 47632        Matt Collins      0.70     US  2014-12-04 00:00:00.000
#
#               Order.ID Order.Priority  ... Sales      Segment  \
# 29117  ES-2011-4436456         Medium  ...   119     Consumer
# 29120  ES-2012-5269514         Medium  ...   160     Consumer
# 29122  IT-2012-1694853       Critical  ...   234    Corporate
# 29125  IT-2012-4790620           High  ...   780  Home Office
# 29127  ES-2013-4250728           High  ...   592    Corporate
# ...                ...            ...  ...   ...          ...
# 47628   CA-2014-100622         Medium  ...     4     Consumer
# 47629   CA-2014-102610         Medium  ...     4     Consumer
# 47630   US-2014-128118            Low  ...    12    Corporate
# 47631   CA-2014-155089           High  ...    46  Home Office
# 47632   US-2014-149510            Low  ...    29     Consumer
#
#                      Ship.Date       Ship.Mode Shipping.Cost  \
# 29117  2011-01-26 00:00:00.000        Same Day         24.75
# 29120  2012-03-30 00:00:00.000     First Class         18.38
# 29122  2012-08-25 00:00:00.000    Second Class         74.18
# 29125  2012-12-24 00:00:00.000    Second Class        113.83
# 29127  2013-06-22 00:00:00.000    Second Class        122.65
# ...                        ...             ...           ...
# 47628  2014-11-08 00:00:00.000  Standard Class          0.27
# 47629  2014-11-09 00:00:00.000  Standard Class          0.27
# 47630  2014-12-02 00:00:00.000  Standard Class          1.72
# 47631  2014-12-07 00:00:00.000  Standard Class          3.44
# 47632  2014-12-11 00:00:00.000  Standard Class          4.13
#
#                    State  Sub.Category  Year        Market2 weeknum
# 29117  Champagne-Ardenne     Bookcases  2011             EU       5
# 29120      Midi-Pyrénées        Chairs  2012             EU      13
# 29122      Midi-Pyrénées        Chairs  2012             EU      34
# 29125   Pays de la Loire       Copiers  2012             EU      51
# 29127      Midi-Pyrénées       Copiers  2013             EU      25
# ...                  ...           ...   ...            ...     ...
# 47628            Florida       Binders  2014  North America      45
# 47629          Tennessee       Binders  2014  North America      45
# 47630          Tennessee       Binders  2014  North America      48
# 47631            Florida       Binders  2014  North America      49
# 47632     North Carolina       Binders  2014  North America      49
#
# [4172 rows x 26 columns]

# %%
(df['Discount']>upper_limit).mean()*100
# Out:
# 8.134139208422694

# %%
df['Discount']=np.where(df['Discount']>upper_limit,
                        upper_limit,
                        np.where(df['Discount']<lower_limit,
                                 lower_limit,
                                 df['Discount']
                                 )
                        )

# %%
df['Discount'][47632]
# Out:
# 0.5

# %%
# Quantity:

# %%
q3=df['Quantity'].quantile(0.75)
q1=df['Quantity'].quantile(0.25)
q3,q1
# Out:
# (5.0, 2.0)

# %%
iqr1=q3-q1
iqr1
# Out:
# 3.0

# %%
u_l=q3+1.5*iqr1
l_l=q1-1.5*iqr1
u_l,l_l
# Out:
# (9.5, -2.5)

# %%
df[df['Quantity']>u_l]
# Out:
#               Category           City        Country Customer.ID  \
# 19     Office Supplies    Los Angeles  United States   NG-184304
# 77     Office Supplies    Los Angeles  United States   GG-146504
# 81     Office Supplies    Los Angeles  United States   AM-103604
# 204    Office Supplies    Los Angeles  United States   CS-124004
# 322    Office Supplies    Los Angeles  United States   MC-176054
# ...                ...            ...            ...         ...
# 51003        Furniture  San Francisco  United States   BC-111254
# 51013       Technology  San Francisco  United States   CM-121154
# 51187       Technology    Los Angeles  United States   MG-181454
# 51248  Office Supplies    Los Angeles  United States   XP-218654
# 51258  Office Supplies    Los Angeles  United States   AP-107204
#
#             Customer.Name  Discount Market               Order.Date  \
# 19          Nathan Gelder       0.0     US  2012-11-22 00:00:00.000
# 77           Greg Guthrie       0.0     US  2011-10-31 00:00:00.000
# 81         Alice McCarthy       0.0     US  2012-03-23 00:00:00.000
# 204    Christopher Schild       0.0     US  2012-10-02 00:00:00.000
# 322          Matt Connell       0.0     US  2013-11-21 00:00:00.000
# ...                   ...       ...    ...                      ...
# 51003       Becky Castell       0.2     US  2014-05-20 00:00:00.000
# 51013        Chad McGuire       0.2     US  2014-10-03 00:00:00.000
# 51187     Mike Gockenbach       0.2     US  2014-10-08 00:00:00.000
# 51248        Xylona Preis       0.2     US  2013-11-04 00:00:00.000
# 51258          Anne Pryor       0.2     US  2013-12-07 00:00:00.000
#
#              Order.ID Order.Priority  ... Sales      Segment  \
# 19     CA-2012-137708           High  ...    43     Consumer
# 77     CA-2011-106439           High  ...    65    Corporate
# 81     US-2012-107944           High  ...   193    Corporate
# 204    US-2012-119312         Medium  ...   270  Home Office
# 322    CA-2013-145492         Medium  ...    39    Corporate
# ...               ...            ...  ...   ...          ...
# 51003  CA-2014-113530         Medium  ...   681  Home Office
# 51013  CA-2014-137414         Medium  ...   369     Consumer
# 51187  CA-2014-108574         Medium  ...    80     Consumer
# 51248  CA-2013-109365         Medium  ...    44     Consumer
# 51258  US-2013-103674         Medium  ...   437  Home Office
#
#                      Ship.Date       Ship.Mode Shipping.Cost       State  \
# 19     2012-11-25 00:00:00.000    Second Class          6.15  California
# 77     2011-11-04 00:00:00.000  Standard Class          6.72  California
# 81     2012-03-25 00:00:00.000     First Class         27.31  California
# 204    2012-10-07 00:00:00.000    Second Class         29.13  California
# 322    2013-11-28 00:00:00.000  Standard Class          2.35  California
# ...                        ...             ...           ...         ...
# 51003  2014-05-22 00:00:00.000    Second Class         73.41  California
# 51013  2014-10-07 00:00:00.000  Standard Class         21.57  California
# 51187  2014-10-12 00:00:00.000  Standard Class          4.78  California
# 51248  2013-11-09 00:00:00.000  Standard Class          4.57  California
# 51258  2013-12-11 00:00:00.000  Standard Class         39.51  California
#
#        Sub.Category  Year        Market2 weeknum
# 19            Paper  2012  North America      47
# 77            Paper  2011  North America      45
# 81            Paper  2012  North America      12
# 204         Storage  2012  North America      40
# 322      Appliances  2013  North America      47
# ...             ...   ...            ...     ...
# 51003        Chairs  2014  North America      21
# 51013      Machines  2014  North America      40
# 51187        Phones  2014  North America      41
# 51248       Binders  2013  North America      45
# 51258       Binders  2013  North America      49
#
# [877 rows x 26 columns]

# %%
(df['Quantity']>u_l).mean()*100
# Out:
# 1.7098849678299863

# %%
df['Quantity']=np.where(df['Quantity']>u_l,
                        u_l,
                        np.where(df['Quantity']<l_l,
                                 l_l,
                                 df['Quantity']
                                 )
                        )

# %%
df['Quantity'][51258]
# Out:
# 9.5

# %%
for i in df[['Discount','Quantity']]:
  plt.figure(figsize=(6,6)),
  sns.boxplot(x=df[i])
  plt.plot()

# %%
df.select_dtypes(include='object').columns
# Out:
# Index(['Category', 'City', 'Country', 'Customer.ID', 'Customer.Name', 'Market',
#        'Order.Date', 'Order.ID', 'Order.Priority', 'Product.ID',
#        'Product.Name', 'Region', 'Segment', 'Ship.Date', 'Ship.Mode', 'State',
#        'Sub.Category', 'Market2'],
#       dtype='object')

# %%
df['Order.Year']=pd.to_datetime(df['Order.Date']).dt.year
df['Order.Month']=pd.to_datetime(df['Order.Date']).dt.month
df['Order.Day']=pd.to_datetime(df['Order.Date']).dt.day

# %%
df['Ship.Year']=pd.to_datetime(df['Ship.Date']).dt.year
df['Ship.Month']=pd.to_datetime(df['Ship.Date']).dt.month
df['Ship.Day']=pd.to_datetime(df['Ship.Date']).dt.day

# %%
df.drop(columns=['Order.Date','Ship.Date','Product.Name','Customer.Name'],inplace=True)

# %%
df1=df.copy()

# %%
x=df1.drop(columns=['Segment'])
y=df1['Segment']

# %% [markdown]
# # **Preprocessing and feature engineering**

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import TargetEncoder
from sklearn.preprocessing import StandardScaler,MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.feature_selection import VarianceThreshold
from sklearn.feature_selection import SelectKBest,chi2,f_classif

# %%
ohe=OneHotEncoder(drop='first',sparse_output=False,handle_unknown='ignore')
le=LabelEncoder()
te=TargetEncoder()
ss=StandardScaler()
ms=MinMaxScaler()
fe1=VarianceThreshold(threshold=0.03)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((41032, 27), (10258, 27), (41032,), (10258,))

# %%
'''Category:3
Market:7
Order.Priority:4
Region:13
Segment:3
Ship.Mode:4
Sub.Category:17
Market2:6'''
# Out:
# 'Category:3\nMarket:7\nOrder.Priority:4\nRegion:13\nSegment:3\nShip.Mode:4\nSub.Category:17\nMarket2:6'

# %%
cat_cols_train=x_train[['Category','Market','Region','Sub.Category','Market2']]
cat_cols_test=x_test[['Category','Market','Region','Sub.Category','Market2']]

# %%
from sklearn import set_config

# %%
ohe1=ohe.set_output(transform='pandas')

# %%
train_ohe=ohe1.fit_transform(cat_cols_train)
test_ohe=ohe1.transform(cat_cols_test)

# %%
train_ohe1=ohe.fit_transform(cat_cols_train)
test_ohe1=ohe.transform(cat_cols_test)

# %%
train_ohe2=pd.DataFrame(train_ohe1,columns=ohe.get_feature_names_out(['Category','Market','Region','Sub.Category','Market2']))

# %%
test_ohe2=pd.DataFrame(test_ohe1,columns=ohe.get_feature_names_out(['Category','Market','Region','Sub.Category','Market2']))

# %%
train_ohe2.shape,test_ohe2.shape
# Out:
# ((41032, 41), (10258, 41))

# %%
x_train.select_dtypes(include='object').columns
# Out:
# Index(['Category', 'City', 'Country', 'Customer.ID', 'Market', 'Order.ID',
#        'Order.Priority', 'Product.ID', 'Region', 'Ship.Mode', 'State',
#        'Sub.Category', 'Market2'],
#       dtype='object')

# %%
x_train['Ship.Mode'].unique()
# Out:
# array(['Standard Class', 'Same Day', 'First Class', 'Second Class'],
#       dtype=object)

# %%
oe1=OrdinalEncoder(categories=[['Low','Medium','High','Critical']])
oe2=OrdinalEncoder(categories=[['First Class','Second Class','Standard Class','Same Day']])

# %%
x_train['Order.Priority']=oe1.fit_transform(x_train[[ 'Order.Priority']])

# %%
x_test['Order.Priority']=oe1.transform(x_test[[ 'Order.Priority']])

# %%
x_train['Ship.Mode']=oe2.fit_transform(x_train[[ 'Ship.Mode']])
x_test['Ship.Mode']=oe2.transform(x_test[[ 'Ship.Mode']])

# %%
df['City'].nunique(),df['Country'].nunique(),df['Product.ID'].nunique(),df['Customer.ID'].nunique(),df['Order.ID'].nunique()
# Out:
# (3636, 147, 10292, 4873, 25035)

# %%
y_train=le.fit_transform(y_train)
y_test=le.transform(y_test)

# %%
df2=df.copy()

# %%
df2['Segment']=le.fit_transform(df2[['Segment']])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
df2.groupby('City')['Segment'].mean()*100
# Out:
# City
# Aachen                    23.529412
# Aalen                      0.000000
# Aalst                    100.000000
# Aba                       76.000000
# Abadan                    90.909091
#                             ...
# Zwedru                     0.000000
# Zwickau                  133.333333
# Zwolle                    50.000000
# eMbalenhle               100.000000
# Águas Lindas de Goiás     50.000000
# Name: Segment, Length: 3636, dtype: float64

# %%
x_train['City']=te.fit_transform(x_train[['City']],y_train)
x_test['City']=te.transform(x_test[['City']])

# %%
x_train['Country']=te.fit_transform(x_train[['Country']],y_train)
x_test['Country']=te.transform(x_test[['Country']])
x_train['Product.ID']=te.fit_transform(x_train[['Product.ID']],y_train)
x_test['Product.ID']=te.transform(x_test[['Product.ID']])
x_train['Customer.ID']=te.fit_transform(x_train[['Customer.ID']],y_train)
x_test['Customer.ID']=te.transform(x_test[['Customer.ID']])
x_train['Order.ID']=te.fit_transform(x_train[['Order.ID']],y_train)
x_test['Order.ID']=te.transform(x_test[['Order.ID']])

# %%
x_train.drop(columns=x_train.select_dtypes(include='object')).shape,train_ohe2.shape
# Out:
# ((41032, 21), (41032, 41))

# %%
train1=pd.concat([x_train.drop(columns=x_train.select_dtypes(include='object')).reset_index(),train_ohe2.reset_index(),],axis=1).drop(columns=['index'])

# %%
test1=pd.concat([x_test.drop(columns=x_test.select_dtypes(include='object')).reset_index(),test_ohe2.reset_index()],axis=1).drop(columns=['index'])

# %%
train1.shape,test1.shape
# Out:
# ((41032, 62), (10258, 62))

# %%
train_x=ss.fit_transform(train1)

# %%
test_x=ss.transform(test1)

# %%
train_x.shape,test_x.shape
# Out:
# ((41032, 62), (10258, 62))

# %%
fe1_train=fe1.fit_transform(train_x)
fe1_test=fe1.transform(test_x)

# %%
fe1.get_support()
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True])

# %%
fe2=SelectKBest(f_classif,k=25)

# %%
an_train=fe2.fit_transform(train_x,y_train)
an_test=fe2.transform(test_x)

# %%
fe2.get_support()
# Out:
# array([ True,  True,  True, False,  True,  True, False, False, False,
#        False, False,  True, False,  True,  True,  True,  True, False,
#         True,  True, False, False, False,  True, False,  True,  True,
#        False, False, False,  True, False, False,  True, False, False,
#        False, False, False, False, False, False,  True,  True,  True,
#        False, False, False, False, False, False, False,  True, False,
#        False,  True, False,  True,  True,  True, False, False])

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
clf1=DecisionTreeClassifier(max_depth=14,random_state=12)

# %%
clf1.fit(train1,y_train)
# Out:
# DecisionTreeClassifier(max_depth=14, random_state=12)

# %%
y_pred=clf1.predict(test1)

# %%
from sklearn.metrics import accuracy_score, precision_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8226749853772666

# %%
precision_score(y_test,y_pred,average='macro')
# Out:
# 0.734862824966446

# %%
cvs=cross_val_score(clf1,train1,y_train,cv=3)

# %%
cvs.mean()
# Out:
# 0.8062000464849902

# %%
clf2=RandomForestClassifier(bootstrap=True,n_estimators=200,random_state=4)

# %%
clf2.fit(an_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=200, random_state=4)

# %%
y_pred1=clf2.predict(an_test)

# %%
accuracy_score(y_test,y_pred1)
# Out:
# 0.858646909728992

# %%
cvs.mean()
# Out:
# 0.8062000464849902
